# %% [markdown]
# <a href="https://colab.research.google.com/github/mlcurva77/UTS_ML2019_ID10885123/blob/master/ML2019_ID10885123_A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nbconvert 
import jinja2 
# !jupyter nbconvert --to pdf --TemplateExporter.exclude_input=True ML2019_ID10885123_A3.ipynb

# %% [markdown]
# # ABC Customer Lifetime Value Initiative {-}

# %% [markdown]
# ## Aims {-}
#
#
# This project is to develop an approach to measure the Customer Lifetime Value (CLV) of a customer in a financial institution called ‘ABC Bank’. The aim is to understand the worth of the customer during the entire relationship with the bank. Knowing the CLV of the customer will help the business develop the best strategies for customer acquisition and retention, and at the same time, improve the company’s profit margin. It is less expensive to keep existing customers than acquiring new ones. Understanding CLV will open up opportunities to strengthen existing customer engagement through developing more personal engagement models based on the CLV.
#
# The bank offers different products to the customers such as Home Loans, Personal Loans, Credit Cards and Transactional accounts. Different teams manage each product. The current challenge is that the customer data across all products are not well integrated. Although a lot of the data is stored in the datawarehouse, some data required for CLV analysis is stored in a separate system or maintained manually.
#
# This initiative will aim to do the following;
#
# * Understand the data requirements for CLV analysis.
# * Integrate all data required for CLV analysis into a common data platform.
# * Determine the customer’s CLV across all product portfolio based on customer engagement and behavior, revenue, and cost of delivering the product to the customer.

# %% [markdown]
# ## Background {-}
#
#
# Currently, the value of the customer is determined by customer behaviour and the revenue contribution of the customer in the last two to five years. The number of years considered is dependent on the time of the marketing campaign being launched. The cost of delivering the product to the customer is not considered in the existing Features and Model Engine. This project will need to understand the relationship between customer engagement, revenue and cost, and incorporate the model into the existing Features and Model Engine. The project will also deliver the changes required to the Execution Platforms to ensure that the CLV of a customer is considered in all engagement channels.
#
# The bank’s data for all the products are stored in a centralized datawarehouse. However, only five years worth of data is stored in the datawarehouse. Older customer data is kept in a big data platform. Some data does not flow from the product systems to the datawarehouse or big data due to gaps in the change management process, security and privacy limitations, and project limitations in bringing new data into the datawarehouse and or big data. Hence, some data will need to be sourced directly from the systems.

# %% [markdown]
# ## Research Project {-}
#
#
# CLV is an important metric to measure the estimated value that a customer can provide to the company over the whole period of the customer and the bank relationship. Increasing the CLV of a customer will drive growth by
#
# * Cost Reduction. It is less expensive to retain existing customers than acquiring new ones. Spending on marketing strategies to find new customers, such as engaging social media channels and salespeople are quite costly and time-consuming. Simply working on your existing customers saves you money on these expenses. Instead, you can focus your resources on tailoring your engagement and services on your current customers which could lead to a better outcome.
# * Prioritised marketing strategies depending on the company’s financial plans and targets. For instance, the bank can roll out a campaign based on customer segments prioritising high-value customers.
# * Improve ROI by determining the balance between customer acquisition, retention and loyalty programs.
#
# ABC Bank has an existing Features and Model Engine used for customer scoring, business decisioning, and marketing campaigns. However, the current model engine does not consider the cost incurred for offering the product to the customer. The model uses customer behaviour and revenue details for calculating the customer score.
#
# The Features and Model Engine will be changed to include the CLV calculation. The profitability of the customer will be evaluated throughout the lifetime relationship of the customer with the bank. The new CLV model will be integrated with different execution platforms such as Customer Onboarding, Marketing, Customer Service, and Insights and Reporting systems. Figure 1 below outlines the high-level data flow of how the CLV engine will integrate with the Data Sources and Execution Platforms.

# %%
inGoogleColab = True
from google.colab import drive 
drive.mount('/content/drive/')

# %%
from IPython.display import Image
Image(filename='/content/drive/My Drive/Machine Learning/CLV_data_flow.png')

# %% [markdown]
# ### CLV Methodology {-}
#
#
# The CLV will be calculated based on the following approach
# * Calculate the profitability of the customer based on current revenue and cost.
# * Determine customer retention and calculate the cohort-based lifetime.
#
# The lifetime of a customer will be calculated based on the current cohort retention matrix. The customer will be mapped based on their tenure to identify their current expected churn rate. The formula to use to determine their lifetime in years is below
#
# $$ Average Lifetime in Years = 1 / Customer Cohort churn rate % $$
#
# Conduct a cohort analysis to determine the predictor variables with the highest correlation with lifetime. The calculation will be automated and will be refreshed every month.
#
# The CLV will then be calculated using the formula below
#
# $$ CLV = Average Lifetime in Years * Profitability of the customer $$

# %%
from IPython.display import Image
Image(filename='/content/drive/My Drive/Machine Learning/CLV_dec_tree.png')

# %% [markdown]
# # Budget and Timeline {-}
#
#
# The project will not require additional equipment or hardware to be installed. It is assumed that the infrastructure necessary for the project is in place.
# The following resources are required to deliver CLV;

# %%
from IPython.display import Image
Image(filename='/content/drive/My Drive/Machine Learning/CLV_roles.png')

# %% [markdown]
# The project is estimated to run in 6 months and the projected cost to deliver the CLV model is $315,000. The impact analysis will take 4 weeks. The impact analysis will be conducted by a Data Engineer. It would involve Data Discovery which includes understanding what data is available and identifying data sources. The Data Architecture and Design is estimated to take 4 weeks. It will involve analysis of the impacted systems, design of data architecture and ETL process. Data Ingestion and Transformation would involve data ingestion, transformation and building data structure to be used for the CLV model. Data Ingestion and Transformation will happen after the Data Architecture and Design have been completed. CLV Features and Model Development will include the design and build of customer cohorts for determining lifetime of the customer based on retention and churn rates. The CLV model will be built during this phase. The development of CLV use cases for marketing application can occur in parallel with the model build. Implementation is planned to be a staggard approach performing pilot testing before the main launch.

# %%
from IPython.display import Image
Image(filename='/content/drive/My Drive/Machine Learning/CLV_budget.png')

# %% [markdown]
# # References {-}
#
# Marketing, Robinson, J.M., 2010. A Customer Lifetime Value-Based Approach to Marketing in the Multichannel , Multimedia Retailing Environment.
#
# Sharma, V., Sonwalkar, J., 2016. Consumer retention strategies for telecom service industry in India: a theoretical perspective. J. Manag. Res. Anal. 3, 110. https://doi.org/10.5958/2394-2770.2016.00017.X
#
# The Benefits of Customer Lifetime Value [WWW Document], n.d. . Cust. Lifetime Value. URL https://www.clv-calculator.com/clv/benefits-customer-lifetime-value/ (accessed 10.7.19).
#
# What Is Customer Lifetime Value (CLV) & How to Measure It? | Qualtrics [WWW Document], n.d. URL https://www.qualtrics.com/experience-management/customer/customer-lifetime-value/ (accessed 10.7.19).
#
# How To Get Your Customer Lifetime Value Right #casestudy, 2017. . Cust. Engagem. Optim. - Inn. Blog. URL https://blog.innertrends.com/customer-lifetime-value/ (accessed 10.7.19).
